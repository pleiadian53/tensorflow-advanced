# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Get the data from UCI dataset
URL = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00242/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URL)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

print(train_stats)

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)
# Out:
#                X1          X2          X3          X4          X5          X6  \
# count  614.000000  614.000000  614.000000  614.000000  614.000000  614.000000
# mean     0.766547  669.999186  317.941368  176.028909    5.267101    3.493485
# std      0.107870   89.306753   42.466163   45.376568    1.751343    1.134851
# min      0.620000  514.500000  245.000000  110.250000    3.500000    2.000000
# 25%      0.690000  588.000000  294.000000  122.500000    3.500000    2.000000
# 50%      0.760000  661.500000  318.500000  147.000000    7.000000    3.000000
# 75%      0.860000  735.000000  343.000000  220.500000    7.000000    5.000000
# max      0.980000  808.500000  416.500000  220.500000    7.000000    5.000000
#
#                X7          X8          Y1          Y2
# count  614.000000  614.000000  614.000000  614.000000
# mean     0.234202    2.863192   22.318381   24.601889
# std      0.133968    1.542497   10.044652    9.448044
# min      0.000000    0.000000    6.010000   10.900000
# 25%      0.100000    2.000000   12.977500   15.575000
# 50%      0.250000    3.000000   19.125000   22.725000
# 75%      0.400000    4.000000   31.877500   33.112500
# max      0.400000    5.000000   43.100000   47.590000

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 252.7848 - y1_output_loss: 122.0622 - y2_output_loss: 128.2985 - y1_output_root_mean_squared_error: 11.1018 - y2_output_root_mean_squared_error: 11.3814 - val_loss: 34.4580 - val_y1_output_loss: 17.2230 - val_y2_output_loss: 18.6809 - val_y1_output_root_mean_squared_error: 4.0164 - val_y2_output_root_mean_squared_error: 4.2809
# Epoch 2/500
# 614/614 [==============================] - 0s 166us/sample - loss: 33.2709 - y1_output_loss: 12.9620 - y2_output_loss: 20.1445 - y1_output_root_mean_squared_error: 3.6134 - y2_output_root_mean_squared_error: 4.4961 - val_loss: 30.0731 - val_y1_output_loss: 11.9014 - val_y2_output_loss: 20.3147 - val_y1_output_root_mean_squared_error: 3.3050 - val_y2_output_root_mean_squared_error: 4.3761
# Epoch 3/500
# 614/614 [==============================] - 0s 139us/sample - loss: 28.7433 - y1_output_loss: 10.7226 - y2_output_loss: 17.9039 - y1_output_root_mean_squared_error: 3.2795 - y2_output_root_mean_squared_error: 4.2412 - val_loss: 18.2904 - val_y1_output_loss: 8.5439 - val_y2_output_loss: 10.1479 - val_y1_output_root_mean_squared_error: 2.8584 - val_y2_output_root_mean_squared_error: 3.1812
# Epoch 4/500
# 614/614 [==============================] - 0s 138us/sample - loss: 24.6361 - y1_output_loss: 9.6901 - y2_output_loss: 15.3407 - y1_output_root_mean_squared_error: 3.1018 - y2_output_root_mean_squared_error: 3.8749 - val_loss: 52.5770 - val_y1_output_loss: 18.0630 - val_y2_output_loss: 37.1983 - val_y1_output_root_mean_squared_error: 4.1002 - val_y2_output_root_mean_squared_error: 5.9804
# Epoch 5/500
# 614/614 [==============================] - 0s 142us/sample - loss: 25.1376 - y1_output_loss: 9.5126 - y2_output_loss: 15.5224 - y1_output_root_mean_squared_error: 3.0929 - y2_output_root_mean_squared_error: 3.9461 - val_loss: 25.2209 - val_y1_output_loss: 10.0583 - val_y2_output_loss: 15.4261 - val_y1_output_root_mean_squared_error: 3.1049 - val_y2_output_root_mean_squared_error: 3.9473
# Epoch 6/500
# 614/614 [==============================] - 0s 144us/sample - loss: 22.9319 - y1_output_loss: 8.7639 - y2_output_loss: 14.0993 - y1_output_root_mean_squared_error: 2.9639 - y2_output_root_mean_squared_error: 3.7613 - val_loss: 21.5103 - val_y1_output_loss: 8.7741 - val_y2_output_loss: 13.0662 - val_y1_output_root_mean_squared_error: 2.8853 - val_y2_output_root_mean_squared_error: 3.6311
# Epoch 7/500
# 614/614 [==============================] - 0s 143us/sample - loss: 20.6295 - y1_output_loss: 8.5633 - y2_output_loss: 12.0526 - y1_output_root_mean_squared_error: 2.9129 - y2_output_root_mean_squared_error: 3.4849 - val_loss: 34.9804 - val_y1_output_loss: 13.0698 - val_y2_output_loss: 21.1331 - val_y1_output_root_mean_squared_error: 3.6355 - val_y2_output_root_mean_squared_error: 4.6652
# Epoch 8/500
# 614/614 [==============================] - 0s 144us/sample - loss: 25.2486 - y1_output_loss: 9.4020 - y2_output_loss: 15.7695 - y1_output_root_mean_squared_error: 3.0684 - y2_output_root_mean_squared_error: 3.9791 - val_loss: 43.8185 - val_y1_output_loss: 13.6484 - val_y2_output_loss: 29.8331 - val_y1_output_root_mean_squared_error: 3.6549 - val_y2_output_root_mean_squared_error: 5.5191
# Epoch 9/500
# 614/614 [==============================] - 0s 135us/sample - loss: 23.7393 - y1_output_loss: 8.6632 - y2_output_loss: 15.0251 - y1_output_root_mean_squared_error: 2.9470 - y2_output_root_mean_squared_error: 3.8800 - val_loss: 21.3164 - val_y1_output_loss: 8.5296 - val_y2_output_loss: 12.4193 - val_y1_output_root_mean_squared_error: 2.9264 - val_y2_output_root_mean_squared_error: 3.5710
# Epoch 10/500
# 614/614 [==============================] - 0s 146us/sample - loss: 18.1992 - y1_output_loss: 7.5051 - y2_output_loss: 10.5833 - y1_output_root_mean_squared_error: 2.7472 - y2_output_root_mean_squared_error: 3.2637 - val_loss: 14.9182 - val_y1_output_loss: 6.5007 - val_y2_output_loss: 8.9755 - val_y1_output_root_mean_squared_error: 2.4699 - val_y2_output_root_mean_squared_error: 2.9695
# Epoch 11/500
# 614/614 [==============================] - 0s 193us/sample - loss: 18.8587 - y1_output_loss: 7.5559 - y2_output_loss: 11.2189 - y1_output_root_mean_squared_error: 2.7608 - y2_output_root_mean_squared_error: 3.3521 - val_loss: 15.4810 - val_y1_output_loss: 6.1611 - val_y2_output_loss: 9.5305 - val_y1_output_root_mean_squared_error: 2.4008 - val_y2_output_root_mean_squared_error: 3.1172
# Epoch 12/500
# 614/614 [==============================] - 0s 131us/sample - loss: 17.8673 - y1_output_loss: 7.2071 - y2_output_loss: 10.5364 - y1_output_root_mean_squared_error: 2.6940 - y2_output_root_mean_squared_error: 3.2572 - val_loss: 13.1656 - val_y1_output_loss: 5.6698 - val_y2_output_loss: 7.8862 - val_y1_output_root_mean_squared_error: 2.3137 - val_y2_output_root_mean_squared_error: 2.7950
# Epoch 13/500
# 614/614 [==============================] - 0s 143us/sample - loss: 20.0743 - y1_output_loss: 7.4268 - y2_output_loss: 12.5261 - y1_output_root_mean_squared_error: 2.7307 - y2_output_root_mean_squared_error: 3.5521 - val_loss: 14.3674 - val_y1_output_loss: 6.5030 - val_y2_output_loss: 8.4433 - val_y1_output_root_mean_squared_error: 2.4604 - val_y2_output_root_mean_squared_error: 2.8834
# Epoch 14/500
# 614/614 [==============================] - 0s 136us/sample - loss: 18.7298 - y1_output_loss: 7.0520 - y2_output_loss: 11.7216 - y1_output_root_mean_squared_error: 2.6545 - y2_output_root_mean_squared_error: 3.4181 - val_loss: 23.6453 - val_y1_output_loss: 7.4607 - val_y2_output_loss: 15.7366 - val_y1_output_root_mean_squared_error: 2.7308 - val_y2_output_root_mean_squared_error: 4.0234
# Epoch 15/500
# 614/614 [==============================] - 0s 136us/sample - loss: 15.6334 - y1_output_loss: 6.1472 - y2_output_loss: 9.5899 - y1_output_root_mean_squared_error: 2.4847 - y2_output_root_mean_squared_error: 3.0757 - val_loss: 20.3969 - val_y1_output_loss: 5.2503 - val_y2_output_loss: 14.9046 - val_y1_output_root_mean_squared_error: 2.2299 - val_y2_output_root_mean_squared_error: 3.9274
# Epoch 16/500
# 614/614 [==============================] - 0s 136us/sample - loss: 16.3957 - y1_output_loss: 6.1595 - y2_output_loss: 10.2146 - y1_output_root_mean_squared_error: 2.4825 - y2_output_root_mean_squared_error: 3.1989 - val_loss: 16.1094 - val_y1_output_loss: 5.8816 - val_y2_output_loss: 10.5832 - val_y1_output_root_mean_squared_error: 2.2951 - val_y2_output_root_mean_squared_error: 3.2927
# Epoch 17/500
# 614/614 [==============================] - 0s 137us/sample - loss: 14.5932 - y1_output_loss: 5.7624 - y2_output_loss: 8.8557 - y1_output_root_mean_squared_error: 2.4001 - y2_output_root_mean_squared_error: 2.9720 - val_loss: 13.8367 - val_y1_output_loss: 6.3731 - val_y2_output_loss: 7.6649 - val_y1_output_root_mean_squared_error: 2.4846 - val_y2_output_root_mean_squared_error: 2.7683
# Epoch 18/500
# 614/614 [==============================] - 0s 138us/sample - loss: 12.9114 - y1_output_loss: 5.0032 - y2_output_loss: 7.8221 - y1_output_root_mean_squared_error: 2.2462 - y2_output_root_mean_squared_error: 2.8047 - val_loss: 12.4430 - val_y1_output_loss: 4.5643 - val_y2_output_loss: 8.2443 - val_y1_output_root_mean_squared_error: 2.0738 - val_y2_output_root_mean_squared_error: 2.8535
# Epoch 19/500
# 614/614 [==============================] - 0s 133us/sample - loss: 14.0031 - y1_output_loss: 5.2672 - y2_output_loss: 8.6266 - y1_output_root_mean_squared_error: 2.3047 - y2_output_root_mean_squared_error: 2.9481 - val_loss: 10.4203 - val_y1_output_loss: 4.3212 - val_y2_output_loss: 6.1757 - val_y1_output_root_mean_squared_error: 2.0359 - val_y2_output_root_mean_squared_error: 2.5051
# Epoch 20/500
# 614/614 [==============================] - 0s 144us/sample - loss: 15.0620 - y1_output_loss: 5.4766 - y2_output_loss: 9.6373 - y1_output_root_mean_squared_error: 2.3473 - y2_output_root_mean_squared_error: 3.0907 - val_loss: 20.3668 - val_y1_output_loss: 4.9931 - val_y2_output_loss: 16.3247 - val_y1_output_root_mean_squared_error: 2.1330 - val_y2_output_root_mean_squared_error: 3.9771
# Epoch 21/500
# 614/614 [==============================] - 0s 140us/sample - loss: 12.5365 - y1_output_loss: 4.9906 - y2_output_loss: 7.5509 - y1_output_root_mean_squared_error: 2.2219 - y2_output_root_mean_squared_error: 2.7568 - val_loss: 16.8775 - val_y1_output_loss: 5.7216 - val_y2_output_loss: 10.7717 - val_y1_output_root_mean_squared_error: 2.4030 - val_y2_output_root_mean_squared_error: 3.3321
# Epoch 22/500
# 614/614 [==============================] - 0s 136us/sample - loss: 12.1095 - y1_output_loss: 4.6699 - y2_output_loss: 7.3347 - y1_output_root_mean_squared_error: 2.1700 - y2_output_root_mean_squared_error: 2.7204 - val_loss: 8.7332 - val_y1_output_loss: 3.2781 - val_y2_output_loss: 5.4835 - val_y1_output_root_mean_squared_error: 1.7620 - val_y2_output_root_mean_squared_error: 2.3725
# Epoch 23/500
# 614/614 [==============================] - 0s 137us/sample - loss: 13.0842 - y1_output_loss: 4.7444 - y2_output_loss: 8.2780 - y1_output_root_mean_squared_error: 2.1786 - y2_output_root_mean_squared_error: 2.8875 - val_loss: 15.5140 - val_y1_output_loss: 5.5216 - val_y2_output_loss: 10.5086 - val_y1_output_root_mean_squared_error: 2.2687 - val_y2_output_root_mean_squared_error: 3.2198
# Epoch 24/500
# 614/614 [==============================] - 0s 132us/sample - loss: 11.6296 - y1_output_loss: 4.1526 - y2_output_loss: 7.5900 - y1_output_root_mean_squared_error: 2.0324 - y2_output_root_mean_squared_error: 2.7384 - val_loss: 37.6659 - val_y1_output_loss: 9.3582 - val_y2_output_loss: 27.9175 - val_y1_output_root_mean_squared_error: 3.0847 - val_y2_output_root_mean_squared_error: 5.3057
# Epoch 25/500
# 614/614 [==============================] - 0s 130us/sample - loss: 12.2593 - y1_output_loss: 4.3989 - y2_output_loss: 7.8299 - y1_output_root_mean_squared_error: 2.1070 - y2_output_root_mean_squared_error: 2.7964 - val_loss: 15.5498 - val_y1_output_loss: 4.6877 - val_y2_output_loss: 11.5521 - val_y1_output_root_mean_squared_error: 2.0610 - val_y2_output_root_mean_squared_error: 3.3619
# Epoch 26/500
# 614/614 [==============================] - 0s 130us/sample - loss: 10.6338 - y1_output_loss: 3.8944 - y2_output_loss: 6.6478 - y1_output_root_mean_squared_error: 1.9812 - y2_output_root_mean_squared_error: 2.5901 - val_loss: 10.2086 - val_y1_output_loss: 3.1098 - val_y2_output_loss: 6.9945 - val_y1_output_root_mean_squared_error: 1.7374 - val_y2_output_root_mean_squared_error: 2.6815
# Epoch 27/500
# 614/614 [==============================] - 0s 131us/sample - loss: 9.8343 - y1_output_loss: 3.5661 - y2_output_loss: 6.3320 - y1_output_root_mean_squared_error: 1.8748 - y2_output_root_mean_squared_error: 2.5139 - val_loss: 8.8644 - val_y1_output_loss: 3.5150 - val_y2_output_loss: 5.3286 - val_y1_output_root_mean_squared_error: 1.8522 - val_y2_output_root_mean_squared_error: 2.3311
# Epoch 28/500
# 614/614 [==============================] - 0s 142us/sample - loss: 13.8733 - y1_output_loss: 4.5820 - y2_output_loss: 9.1744 - y1_output_root_mean_squared_error: 2.1473 - y2_output_root_mean_squared_error: 3.0434 - val_loss: 8.0803 - val_y1_output_loss: 2.9671 - val_y2_output_loss: 5.4218 - val_y1_output_root_mean_squared_error: 1.6216 - val_y2_output_root_mean_squared_error: 2.3347
# Epoch 29/500
# 614/614 [==============================] - 0s 141us/sample - loss: 9.0693 - y1_output_loss: 3.2349 - y2_output_loss: 5.8992 - y1_output_root_mean_squared_error: 1.7939 - y2_output_root_mean_squared_error: 2.4189 - val_loss: 9.4016 - val_y1_output_loss: 3.5477 - val_y2_output_loss: 6.1045 - val_y1_output_root_mean_squared_error: 1.8081 - val_y2_output_root_mean_squared_error: 2.4764
# Epoch 30/500
# 614/614 [==============================] - 0s 133us/sample - loss: 8.6698 - y1_output_loss: 3.1470 - y2_output_loss: 5.5432 - y1_output_root_mean_squared_error: 1.7660 - y2_output_root_mean_squared_error: 2.3561 - val_loss: 14.5250 - val_y1_output_loss: 5.3376 - val_y2_output_loss: 9.2353 - val_y1_output_root_mean_squared_error: 2.2566 - val_y2_output_root_mean_squared_error: 3.0713
# Epoch 31/500
# 614/614 [==============================] - 0s 136us/sample - loss: 12.5323 - y1_output_loss: 4.1360 - y2_output_loss: 8.3113 - y1_output_root_mean_squared_error: 2.0422 - y2_output_root_mean_squared_error: 2.8916 - val_loss: 9.3884 - val_y1_output_loss: 3.0331 - val_y2_output_loss: 6.6894 - val_y1_output_root_mean_squared_error: 1.6596 - val_y2_output_root_mean_squared_error: 2.5757
# Epoch 32/500
# 614/614 [==============================] - 0s 150us/sample - loss: 9.1419 - y1_output_loss: 3.2769 - y2_output_loss: 5.9389 - y1_output_root_mean_squared_error: 1.8052 - y2_output_root_mean_squared_error: 2.4255 - val_loss: 59.9037 - val_y1_output_loss: 9.7116 - val_y2_output_loss: 51.4709 - val_y1_output_root_mean_squared_error: 3.0150 - val_y2_output_root_mean_squared_error: 7.1284
# Epoch 33/500
# 614/614 [==============================] - 0s 131us/sample - loss: 8.4728 - y1_output_loss: 2.9402 - y2_output_loss: 5.5221 - y1_output_root_mean_squared_error: 1.7064 - y2_output_root_mean_squared_error: 2.3582 - val_loss: 14.1124 - val_y1_output_loss: 3.3212 - val_y2_output_loss: 10.5747 - val_y1_output_root_mean_squared_error: 1.8151 - val_y2_output_root_mean_squared_error: 3.2890
# Epoch 34/500
# 614/614 [==============================] - 0s 136us/sample - loss: 8.5572 - y1_output_loss: 2.9017 - y2_output_loss: 5.6866 - y1_output_root_mean_squared_error: 1.7013 - y2_output_root_mean_squared_error: 2.3796 - val_loss: 7.0866 - val_y1_output_loss: 2.4454 - val_y2_output_loss: 4.7618 - val_y1_output_root_mean_squared_error: 1.4963 - val_y2_output_root_mean_squared_error: 2.2018
# Epoch 35/500
# 614/614 [==============================] - 0s 141us/sample - loss: 7.4709 - y1_output_loss: 2.5705 - y2_output_loss: 4.8833 - y1_output_root_mean_squared_error: 1.6012 - y2_output_root_mean_squared_error: 2.2152 - val_loss: 8.8876 - val_y1_output_loss: 3.6719 - val_y2_output_loss: 5.4378 - val_y1_output_root_mean_squared_error: 1.8309 - val_y2_output_root_mean_squared_error: 2.3528
# Epoch 36/500
# 614/614 [==============================] - 0s 136us/sample - loss: 8.1291 - y1_output_loss: 2.5675 - y2_output_loss: 5.5318 - y1_output_root_mean_squared_error: 1.6053 - y2_output_root_mean_squared_error: 2.3563 - val_loss: 14.1745 - val_y1_output_loss: 4.5404 - val_y2_output_loss: 9.3212 - val_y1_output_root_mean_squared_error: 2.1668 - val_y2_output_root_mean_squared_error: 3.0789
# Epoch 37/500
# 614/614 [==============================] - 0s 136us/sample - loss: 8.2457 - y1_output_loss: 2.5679 - y2_output_loss: 5.6134 - y1_output_root_mean_squared_error: 1.6085 - y2_output_root_mean_squared_error: 2.3787 - val_loss: 10.2688 - val_y1_output_loss: 2.8334 - val_y2_output_loss: 7.2954 - val_y1_output_root_mean_squared_error: 1.6770 - val_y2_output_root_mean_squared_error: 2.7307
# Epoch 38/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.5685 - y1_output_loss: 2.4316 - y2_output_loss: 4.1117 - y1_output_root_mean_squared_error: 1.5568 - y2_output_root_mean_squared_error: 2.0359 - val_loss: 6.7268 - val_y1_output_loss: 2.2780 - val_y2_output_loss: 4.6879 - val_y1_output_root_mean_squared_error: 1.4158 - val_y2_output_root_mean_squared_error: 2.1731
# Epoch 39/500
# 614/614 [==============================] - 0s 129us/sample - loss: 10.1890 - y1_output_loss: 3.0291 - y2_output_loss: 7.1218 - y1_output_root_mean_squared_error: 1.7458 - y2_output_root_mean_squared_error: 2.6723 - val_loss: 10.3473 - val_y1_output_loss: 3.3388 - val_y2_output_loss: 6.7989 - val_y1_output_root_mean_squared_error: 1.8419 - val_y2_output_root_mean_squared_error: 2.6372
# Epoch 40/500
# 614/614 [==============================] - 0s 136us/sample - loss: 7.2434 - y1_output_loss: 2.4864 - y2_output_loss: 4.7590 - y1_output_root_mean_squared_error: 1.5743 - y2_output_root_mean_squared_error: 2.1829 - val_loss: 6.5640 - val_y1_output_loss: 2.2309 - val_y2_output_loss: 4.6036 - val_y1_output_root_mean_squared_error: 1.4007 - val_y2_output_root_mean_squared_error: 2.1453
# Epoch 41/500
# 614/614 [==============================] - 0s 129us/sample - loss: 8.0679 - y1_output_loss: 2.5075 - y2_output_loss: 5.5237 - y1_output_root_mean_squared_error: 1.5843 - y2_output_root_mean_squared_error: 2.3575 - val_loss: 16.0175 - val_y1_output_loss: 3.3435 - val_y2_output_loss: 12.3323 - val_y1_output_root_mean_squared_error: 1.8603 - val_y2_output_root_mean_squared_error: 3.5436
# Epoch 42/500
# 614/614 [==============================] - 0s 130us/sample - loss: 7.7996 - y1_output_loss: 2.3682 - y2_output_loss: 5.3921 - y1_output_root_mean_squared_error: 1.5369 - y2_output_root_mean_squared_error: 2.3318 - val_loss: 6.0014 - val_y1_output_loss: 1.6096 - val_y2_output_loss: 4.3108 - val_y1_output_root_mean_squared_error: 1.2557 - val_y2_output_root_mean_squared_error: 2.1034
# Epoch 43/500
# 614/614 [==============================] - 0s 136us/sample - loss: 6.9284 - y1_output_loss: 2.0006 - y2_output_loss: 4.8892 - y1_output_root_mean_squared_error: 1.4188 - y2_output_root_mean_squared_error: 2.2171 - val_loss: 5.9515 - val_y1_output_loss: 2.1136 - val_y2_output_loss: 3.7491 - val_y1_output_root_mean_squared_error: 1.4542 - val_y2_output_root_mean_squared_error: 1.9588
# Epoch 44/500
# 614/614 [==============================] - 0s 136us/sample - loss: 6.6477 - y1_output_loss: 2.0466 - y2_output_loss: 4.5821 - y1_output_root_mean_squared_error: 1.4340 - y2_output_root_mean_squared_error: 2.1427 - val_loss: 10.5335 - val_y1_output_loss: 4.2856 - val_y2_output_loss: 6.8016 - val_y1_output_root_mean_squared_error: 1.9462 - val_y2_output_root_mean_squared_error: 2.5973
# Epoch 45/500
# 614/614 [==============================] - 0s 134us/sample - loss: 7.1866 - y1_output_loss: 2.1803 - y2_output_loss: 4.9647 - y1_output_root_mean_squared_error: 1.4828 - y2_output_root_mean_squared_error: 2.2334 - val_loss: 5.1413 - val_y1_output_loss: 1.3503 - val_y2_output_loss: 3.7612 - val_y1_output_root_mean_squared_error: 1.1411 - val_y2_output_root_mean_squared_error: 1.9594
# Epoch 46/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.6703 - y1_output_loss: 2.1861 - y2_output_loss: 4.5887 - y1_output_root_mean_squared_error: 1.4709 - y2_output_root_mean_squared_error: 2.1229 - val_loss: 7.7769 - val_y1_output_loss: 2.0445 - val_y2_output_loss: 5.5281 - val_y1_output_root_mean_squared_error: 1.4345 - val_y2_output_root_mean_squared_error: 2.3915
# Epoch 47/500
# 614/614 [==============================] - 0s 129us/sample - loss: 9.6198 - y1_output_loss: 2.8537 - y2_output_loss: 6.7280 - y1_output_root_mean_squared_error: 1.6934 - y2_output_root_mean_squared_error: 2.5985 - val_loss: 5.9241 - val_y1_output_loss: 1.7751 - val_y2_output_loss: 4.2711 - val_y1_output_root_mean_squared_error: 1.2666 - val_y2_output_root_mean_squared_error: 2.0784
# Epoch 48/500
# 614/614 [==============================] - 0s 128us/sample - loss: 7.1433 - y1_output_loss: 2.1351 - y2_output_loss: 4.9798 - y1_output_root_mean_squared_error: 1.4565 - y2_output_root_mean_squared_error: 2.2410 - val_loss: 6.5594 - val_y1_output_loss: 2.6739 - val_y2_output_loss: 4.3232 - val_y1_output_root_mean_squared_error: 1.5047 - val_y2_output_root_mean_squared_error: 2.0725
# Epoch 49/500
# 614/614 [==============================] - 0s 128us/sample - loss: 5.7774 - y1_output_loss: 1.9842 - y2_output_loss: 3.8150 - y1_output_root_mean_squared_error: 1.4099 - y2_output_root_mean_squared_error: 1.9467 - val_loss: 9.9351 - val_y1_output_loss: 3.6514 - val_y2_output_loss: 6.6810 - val_y1_output_root_mean_squared_error: 1.8128 - val_y2_output_root_mean_squared_error: 2.5786
# Epoch 50/500
# 614/614 [==============================] - 0s 139us/sample - loss: 6.1105 - y1_output_loss: 1.7074 - y2_output_loss: 4.3948 - y1_output_root_mean_squared_error: 1.3083 - y2_output_root_mean_squared_error: 2.0974 - val_loss: 6.7549 - val_y1_output_loss: 2.3942 - val_y2_output_loss: 4.5445 - val_y1_output_root_mean_squared_error: 1.4480 - val_y2_output_root_mean_squared_error: 2.1583
# Epoch 51/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.4279 - y1_output_loss: 1.6744 - y2_output_loss: 3.7119 - y1_output_root_mean_squared_error: 1.2979 - y2_output_root_mean_squared_error: 1.9348 - val_loss: 5.9348 - val_y1_output_loss: 1.4465 - val_y2_output_loss: 4.3653 - val_y1_output_root_mean_squared_error: 1.1914 - val_y2_output_root_mean_squared_error: 2.1250
# Epoch 52/500
# 614/614 [==============================] - 0s 134us/sample - loss: 5.9674 - y1_output_loss: 1.8631 - y2_output_loss: 4.0795 - y1_output_root_mean_squared_error: 1.3653 - y2_output_root_mean_squared_error: 2.0256 - val_loss: 5.8496 - val_y1_output_loss: 1.6557 - val_y2_output_loss: 4.2905 - val_y1_output_root_mean_squared_error: 1.2295 - val_y2_output_root_mean_squared_error: 2.0828
# Epoch 53/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.7143 - y1_output_loss: 2.0711 - y2_output_loss: 4.6143 - y1_output_root_mean_squared_error: 1.4427 - y2_output_root_mean_squared_error: 2.1524 - val_loss: 9.2495 - val_y1_output_loss: 2.6851 - val_y2_output_loss: 7.0247 - val_y1_output_root_mean_squared_error: 1.5291 - val_y2_output_root_mean_squared_error: 2.6289
# Epoch 54/500
# 614/614 [==============================] - 0s 137us/sample - loss: 5.1670 - y1_output_loss: 1.4827 - y2_output_loss: 3.6458 - y1_output_root_mean_squared_error: 1.2210 - y2_output_root_mean_squared_error: 1.9173 - val_loss: 5.5484 - val_y1_output_loss: 1.6742 - val_y2_output_loss: 4.0116 - val_y1_output_root_mean_squared_error: 1.2152 - val_y2_output_root_mean_squared_error: 2.0178
# Epoch 55/500
# 614/614 [==============================] - 0s 134us/sample - loss: 6.2449 - y1_output_loss: 1.8529 - y2_output_loss: 4.3786 - y1_output_root_mean_squared_error: 1.3588 - y2_output_root_mean_squared_error: 2.0973 - val_loss: 6.8213 - val_y1_output_loss: 2.2197 - val_y2_output_loss: 4.5093 - val_y1_output_root_mean_squared_error: 1.4768 - val_y2_output_root_mean_squared_error: 2.1542
# Epoch 56/500
# 614/614 [==============================] - 0s 131us/sample - loss: 5.5882 - y1_output_loss: 1.7572 - y2_output_loss: 3.8144 - y1_output_root_mean_squared_error: 1.3227 - y2_output_root_mean_squared_error: 1.9593 - val_loss: 6.2202 - val_y1_output_loss: 2.0069 - val_y2_output_loss: 4.0437 - val_y1_output_root_mean_squared_error: 1.4267 - val_y2_output_root_mean_squared_error: 2.0456
# Epoch 57/500
# 614/614 [==============================] - 0s 138us/sample - loss: 6.7281 - y1_output_loss: 2.1480 - y2_output_loss: 4.6290 - y1_output_root_mean_squared_error: 1.4708 - y2_output_root_mean_squared_error: 2.1365 - val_loss: 14.0036 - val_y1_output_loss: 4.5101 - val_y2_output_loss: 10.3077 - val_y1_output_root_mean_squared_error: 1.9929 - val_y2_output_root_mean_squared_error: 3.1673
# Epoch 58/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.0057 - y1_output_loss: 1.4929 - y2_output_loss: 3.4677 - y1_output_root_mean_squared_error: 1.2271 - y2_output_root_mean_squared_error: 1.8708 - val_loss: 5.1036 - val_y1_output_loss: 1.5048 - val_y2_output_loss: 3.6173 - val_y1_output_root_mean_squared_error: 1.1794 - val_y2_output_root_mean_squared_error: 1.9268
# Epoch 59/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.0817 - y1_output_loss: 1.5765 - y2_output_loss: 4.5112 - y1_output_root_mean_squared_error: 1.2575 - y2_output_root_mean_squared_error: 2.1214 - val_loss: 11.6788 - val_y1_output_loss: 4.0534 - val_y2_output_loss: 7.4699 - val_y1_output_root_mean_squared_error: 2.0353 - val_y2_output_root_mean_squared_error: 2.7452
# Epoch 60/500
# 614/614 [==============================] - 0s 141us/sample - loss: 4.7945 - y1_output_loss: 1.2832 - y2_output_loss: 3.4832 - y1_output_root_mean_squared_error: 1.1364 - y2_output_root_mean_squared_error: 1.8716 - val_loss: 5.7580 - val_y1_output_loss: 1.3578 - val_y2_output_loss: 4.3088 - val_y1_output_root_mean_squared_error: 1.1359 - val_y2_output_root_mean_squared_error: 2.1137
# Epoch 61/500
# 614/614 [==============================] - 0s 138us/sample - loss: 8.2953 - y1_output_loss: 2.3212 - y2_output_loss: 5.9499 - y1_output_root_mean_squared_error: 1.5246 - y2_output_root_mean_squared_error: 2.4435 - val_loss: 6.4550 - val_y1_output_loss: 1.4315 - val_y2_output_loss: 5.0645 - val_y1_output_root_mean_squared_error: 1.1557 - val_y2_output_root_mean_squared_error: 2.2626
# Epoch 62/500
# 614/614 [==============================] - 0s 137us/sample - loss: 6.0268 - y1_output_loss: 1.7245 - y2_output_loss: 4.2579 - y1_output_root_mean_squared_error: 1.3161 - y2_output_root_mean_squared_error: 2.0724 - val_loss: 6.8396 - val_y1_output_loss: 1.8538 - val_y2_output_loss: 4.8632 - val_y1_output_root_mean_squared_error: 1.3509 - val_y2_output_root_mean_squared_error: 2.2394
# Epoch 63/500
# 614/614 [==============================] - 0s 133us/sample - loss: 6.1575 - y1_output_loss: 1.7743 - y2_output_loss: 4.3759 - y1_output_root_mean_squared_error: 1.3376 - y2_output_root_mean_squared_error: 2.0900 - val_loss: 4.9493 - val_y1_output_loss: 1.0443 - val_y2_output_loss: 3.9196 - val_y1_output_root_mean_squared_error: 1.0007 - val_y2_output_root_mean_squared_error: 1.9869
# Epoch 64/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.4415 - y1_output_loss: 1.2916 - y2_output_loss: 3.1243 - y1_output_root_mean_squared_error: 1.1391 - y2_output_root_mean_squared_error: 1.7731 - val_loss: 5.4634 - val_y1_output_loss: 1.0215 - val_y2_output_loss: 4.4133 - val_y1_output_root_mean_squared_error: 0.9464 - val_y2_output_root_mean_squared_error: 2.1372
# Epoch 65/500
# 614/614 [==============================] - 0s 132us/sample - loss: 6.5834 - y1_output_loss: 1.7811 - y2_output_loss: 4.7437 - y1_output_root_mean_squared_error: 1.3394 - y2_output_root_mean_squared_error: 2.1885 - val_loss: 5.2192 - val_y1_output_loss: 1.4185 - val_y2_output_loss: 3.6867 - val_y1_output_root_mean_squared_error: 1.1923 - val_y2_output_root_mean_squared_error: 1.9487
# Epoch 66/500
# 614/614 [==============================] - 0s 130us/sample - loss: 7.0341 - y1_output_loss: 2.1841 - y2_output_loss: 4.8084 - y1_output_root_mean_squared_error: 1.4788 - y2_output_root_mean_squared_error: 2.2017 - val_loss: 6.3366 - val_y1_output_loss: 1.5285 - val_y2_output_loss: 4.6444 - val_y1_output_root_mean_squared_error: 1.2405 - val_y2_output_root_mean_squared_error: 2.1904
# Epoch 67/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.0920 - y1_output_loss: 1.0594 - y2_output_loss: 3.0021 - y1_output_root_mean_squared_error: 1.0330 - y2_output_root_mean_squared_error: 1.7392 - val_loss: 5.7063 - val_y1_output_loss: 1.4207 - val_y2_output_loss: 4.4600 - val_y1_output_root_mean_squared_error: 1.1057 - val_y2_output_root_mean_squared_error: 2.1175
# Epoch 68/500
# 614/614 [==============================] - 0s 140us/sample - loss: 4.3449 - y1_output_loss: 1.0728 - y2_output_loss: 3.2596 - y1_output_root_mean_squared_error: 1.0367 - y2_output_root_mean_squared_error: 1.8083 - val_loss: 5.6189 - val_y1_output_loss: 0.9398 - val_y2_output_loss: 4.8023 - val_y1_output_root_mean_squared_error: 0.8933 - val_y2_output_root_mean_squared_error: 2.1957
# Epoch 69/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.3198 - y1_output_loss: 1.1888 - y2_output_loss: 3.1025 - y1_output_root_mean_squared_error: 1.0918 - y2_output_root_mean_squared_error: 1.7686 - val_loss: 4.4577 - val_y1_output_loss: 1.2191 - val_y2_output_loss: 3.2883 - val_y1_output_root_mean_squared_error: 1.0439 - val_y2_output_root_mean_squared_error: 1.8352
# Epoch 70/500
# 614/614 [==============================] - 0s 135us/sample - loss: 8.2023 - y1_output_loss: 2.3398 - y2_output_loss: 5.8194 - y1_output_root_mean_squared_error: 1.5362 - y2_output_root_mean_squared_error: 2.4171 - val_loss: 4.2067 - val_y1_output_loss: 1.0386 - val_y2_output_loss: 3.0830 - val_y1_output_root_mean_squared_error: 1.0294 - val_y2_output_root_mean_squared_error: 1.7740
# Epoch 71/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.8439 - y1_output_loss: 0.9431 - y2_output_loss: 2.8826 - y1_output_root_mean_squared_error: 0.9738 - y2_output_root_mean_squared_error: 1.7016 - val_loss: 4.6935 - val_y1_output_loss: 1.3398 - val_y2_output_loss: 3.5532 - val_y1_output_root_mean_squared_error: 1.0659 - val_y2_output_root_mean_squared_error: 1.8861
# Epoch 72/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.8444 - y1_output_loss: 1.1343 - y2_output_loss: 3.6850 - y1_output_root_mean_squared_error: 1.0669 - y2_output_root_mean_squared_error: 1.9251 - val_loss: 3.9012 - val_y1_output_loss: 0.9135 - val_y2_output_loss: 3.0537 - val_y1_output_root_mean_squared_error: 0.8926 - val_y2_output_root_mean_squared_error: 1.7619
# Epoch 73/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.4536 - y1_output_loss: 0.8754 - y2_output_loss: 2.5578 - y1_output_root_mean_squared_error: 0.9391 - y2_output_root_mean_squared_error: 1.6037 - val_loss: 4.9780 - val_y1_output_loss: 0.9108 - val_y2_output_loss: 3.9733 - val_y1_output_root_mean_squared_error: 0.9465 - val_y2_output_root_mean_squared_error: 2.0204
# Epoch 74/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.0760 - y1_output_loss: 1.0518 - y2_output_loss: 3.0510 - y1_output_root_mean_squared_error: 1.0287 - y2_output_root_mean_squared_error: 1.7372 - val_loss: 23.3323 - val_y1_output_loss: 6.5119 - val_y2_output_loss: 16.8387 - val_y1_output_root_mean_squared_error: 2.5558 - val_y2_output_root_mean_squared_error: 4.0988
# Epoch 75/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.3735 - y1_output_loss: 1.2036 - y2_output_loss: 4.1250 - y1_output_root_mean_squared_error: 1.1018 - y2_output_root_mean_squared_error: 2.0395 - val_loss: 8.7315 - val_y1_output_loss: 2.0339 - val_y2_output_loss: 6.9051 - val_y1_output_root_mean_squared_error: 1.3542 - val_y2_output_root_mean_squared_error: 2.6263
# Epoch 76/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.4029 - y1_output_loss: 1.1183 - y2_output_loss: 3.3120 - y1_output_root_mean_squared_error: 1.0605 - y2_output_root_mean_squared_error: 1.8106 - val_loss: 12.2452 - val_y1_output_loss: 2.9260 - val_y2_output_loss: 9.8210 - val_y1_output_root_mean_squared_error: 1.6087 - val_y2_output_root_mean_squared_error: 3.1076
# Epoch 77/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.0524 - y1_output_loss: 0.9667 - y2_output_loss: 3.1030 - y1_output_root_mean_squared_error: 0.9850 - y2_output_root_mean_squared_error: 1.7556 - val_loss: 3.8582 - val_y1_output_loss: 0.9614 - val_y2_output_loss: 3.0073 - val_y1_output_root_mean_squared_error: 0.8839 - val_y2_output_root_mean_squared_error: 1.7541
# Epoch 78/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.9487 - y1_output_loss: 0.7943 - y2_output_loss: 2.1326 - y1_output_root_mean_squared_error: 0.8942 - y2_output_root_mean_squared_error: 1.4660 - val_loss: 3.8759 - val_y1_output_loss: 0.6664 - val_y2_output_loss: 3.1374 - val_y1_output_root_mean_squared_error: 0.8014 - val_y2_output_root_mean_squared_error: 1.7982
# Epoch 79/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.9697 - y1_output_loss: 0.9076 - y2_output_loss: 3.0952 - y1_output_root_mean_squared_error: 0.9470 - y2_output_root_mean_squared_error: 1.7529 - val_loss: 9.6186 - val_y1_output_loss: 2.0813 - val_y2_output_loss: 7.5239 - val_y1_output_root_mean_squared_error: 1.3958 - val_y2_output_root_mean_squared_error: 2.7696
# Epoch 80/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.9673 - y1_output_loss: 0.7075 - y2_output_loss: 2.2435 - y1_output_root_mean_squared_error: 0.8406 - y2_output_root_mean_squared_error: 1.5036 - val_loss: 3.9983 - val_y1_output_loss: 0.7910 - val_y2_output_loss: 3.1082 - val_y1_output_root_mean_squared_error: 0.8806 - val_y2_output_root_mean_squared_error: 1.7952
# Epoch 81/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.7000 - y1_output_loss: 0.9958 - y2_output_loss: 2.6715 - y1_output_root_mean_squared_error: 1.0022 - y2_output_root_mean_squared_error: 1.6418 - val_loss: 3.2196 - val_y1_output_loss: 0.6887 - val_y2_output_loss: 2.5518 - val_y1_output_root_mean_squared_error: 0.7744 - val_y2_output_root_mean_squared_error: 1.6186
# Epoch 82/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.1872 - y1_output_loss: 0.7433 - y2_output_loss: 2.4249 - y1_output_root_mean_squared_error: 0.8643 - y2_output_root_mean_squared_error: 1.5621 - val_loss: 3.4708 - val_y1_output_loss: 0.8007 - val_y2_output_loss: 2.7049 - val_y1_output_root_mean_squared_error: 0.8330 - val_y2_output_root_mean_squared_error: 1.6664
# Epoch 83/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.2140 - y1_output_loss: 0.7627 - y2_output_loss: 2.4427 - y1_output_root_mean_squared_error: 0.8713 - y2_output_root_mean_squared_error: 1.5668 - val_loss: 5.8721 - val_y1_output_loss: 0.8297 - val_y2_output_loss: 4.9164 - val_y1_output_root_mean_squared_error: 0.9114 - val_y2_output_root_mean_squared_error: 2.2453
# Epoch 84/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.6094 - y1_output_loss: 0.5604 - y2_output_loss: 2.0416 - y1_output_root_mean_squared_error: 0.7491 - y2_output_root_mean_squared_error: 1.4312 - val_loss: 3.4641 - val_y1_output_loss: 0.6576 - val_y2_output_loss: 2.9028 - val_y1_output_root_mean_squared_error: 0.7396 - val_y2_output_root_mean_squared_error: 1.7080
# Epoch 85/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.1680 - y1_output_loss: 0.6875 - y2_output_loss: 2.4587 - y1_output_root_mean_squared_error: 0.8303 - y2_output_root_mean_squared_error: 1.5744 - val_loss: 3.5997 - val_y1_output_loss: 0.9711 - val_y2_output_loss: 2.5830 - val_y1_output_root_mean_squared_error: 0.9806 - val_y2_output_root_mean_squared_error: 1.6242
# Epoch 86/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.1634 - y1_output_loss: 0.7888 - y2_output_loss: 2.3944 - y1_output_root_mean_squared_error: 0.8919 - y2_output_root_mean_squared_error: 1.5388 - val_loss: 10.0290 - val_y1_output_loss: 0.7992 - val_y2_output_loss: 9.2386 - val_y1_output_root_mean_squared_error: 0.8527 - val_y2_output_root_mean_squared_error: 3.0499
# Epoch 87/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.7196 - y1_output_loss: 1.3104 - y2_output_loss: 3.4423 - y1_output_root_mean_squared_error: 1.1470 - y2_output_root_mean_squared_error: 1.8450 - val_loss: 6.8173 - val_y1_output_loss: 0.9719 - val_y2_output_loss: 5.8824 - val_y1_output_root_mean_squared_error: 0.9448 - val_y2_output_root_mean_squared_error: 2.4340
# Epoch 88/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.4248 - y1_output_loss: 0.5719 - y2_output_loss: 1.8443 - y1_output_root_mean_squared_error: 0.7585 - y2_output_root_mean_squared_error: 1.3599 - val_loss: 2.9470 - val_y1_output_loss: 0.5543 - val_y2_output_loss: 2.3952 - val_y1_output_root_mean_squared_error: 0.6927 - val_y2_output_root_mean_squared_error: 1.5707
# Epoch 89/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.4222 - y1_output_loss: 0.7237 - y2_output_loss: 2.6721 - y1_output_root_mean_squared_error: 0.8542 - y2_output_root_mean_squared_error: 1.6409 - val_loss: 3.8468 - val_y1_output_loss: 1.1077 - val_y2_output_loss: 2.8051 - val_y1_output_root_mean_squared_error: 0.9878 - val_y2_output_root_mean_squared_error: 1.6944
# Epoch 90/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.0676 - y1_output_loss: 0.6837 - y2_output_loss: 2.3765 - y1_output_root_mean_squared_error: 0.8291 - y2_output_root_mean_squared_error: 1.5428 - val_loss: 3.0551 - val_y1_output_loss: 0.6137 - val_y2_output_loss: 2.4563 - val_y1_output_root_mean_squared_error: 0.7519 - val_y2_output_root_mean_squared_error: 1.5779
# Epoch 91/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.6997 - y1_output_loss: 0.8899 - y2_output_loss: 2.8123 - y1_output_root_mean_squared_error: 0.9326 - y2_output_root_mean_squared_error: 1.6822 - val_loss: 3.7736 - val_y1_output_loss: 0.9434 - val_y2_output_loss: 2.8114 - val_y1_output_root_mean_squared_error: 0.9431 - val_y2_output_root_mean_squared_error: 1.6983
# Epoch 92/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.2483 - y1_output_loss: 1.4528 - y2_output_loss: 3.8623 - y1_output_root_mean_squared_error: 1.1837 - y2_output_root_mean_squared_error: 1.9614 - val_loss: 14.0608 - val_y1_output_loss: 5.4733 - val_y2_output_loss: 8.3006 - val_y1_output_root_mean_squared_error: 2.3588 - val_y2_output_root_mean_squared_error: 2.9150
# Epoch 93/500
# 614/614 [==============================] - 0s 146us/sample - loss: 4.0169 - y1_output_loss: 1.0974 - y2_output_loss: 2.8833 - y1_output_root_mean_squared_error: 1.0525 - y2_output_root_mean_squared_error: 1.7056 - val_loss: 2.6487 - val_y1_output_loss: 0.5210 - val_y2_output_loss: 2.1367 - val_y1_output_root_mean_squared_error: 0.6829 - val_y2_output_root_mean_squared_error: 1.4773
# Epoch 94/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.4387 - y1_output_loss: 0.5302 - y2_output_loss: 1.9542 - y1_output_root_mean_squared_error: 0.7231 - y2_output_root_mean_squared_error: 1.3841 - val_loss: 3.8308 - val_y1_output_loss: 0.7398 - val_y2_output_loss: 3.1952 - val_y1_output_root_mean_squared_error: 0.8037 - val_y2_output_root_mean_squared_error: 1.7846
# Epoch 95/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.1222 - y1_output_loss: 0.7511 - y2_output_loss: 2.3609 - y1_output_root_mean_squared_error: 0.8635 - y2_output_root_mean_squared_error: 1.5416 - val_loss: 3.5184 - val_y1_output_loss: 0.5941 - val_y2_output_loss: 2.8587 - val_y1_output_root_mean_squared_error: 0.7547 - val_y2_output_root_mean_squared_error: 1.7172
# Epoch 96/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.9876 - y1_output_loss: 0.6170 - y2_output_loss: 2.3486 - y1_output_root_mean_squared_error: 0.7874 - y2_output_root_mean_squared_error: 1.5387 - val_loss: 4.5986 - val_y1_output_loss: 1.1877 - val_y2_output_loss: 3.6432 - val_y1_output_root_mean_squared_error: 1.0005 - val_y2_output_root_mean_squared_error: 1.8967
# Epoch 97/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.7023 - y1_output_loss: 0.6013 - y2_output_loss: 2.0833 - y1_output_root_mean_squared_error: 0.7767 - y2_output_root_mean_squared_error: 1.4488 - val_loss: 3.0008 - val_y1_output_loss: 0.5433 - val_y2_output_loss: 2.4131 - val_y1_output_root_mean_squared_error: 0.7222 - val_y2_output_root_mean_squared_error: 1.5746
# Epoch 98/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.3741 - y1_output_loss: 0.5376 - y2_output_loss: 1.8419 - y1_output_root_mean_squared_error: 0.7356 - y2_output_root_mean_squared_error: 1.3539 - val_loss: 3.2478 - val_y1_output_loss: 0.7527 - val_y2_output_loss: 2.4488 - val_y1_output_root_mean_squared_error: 0.8514 - val_y2_output_root_mean_squared_error: 1.5884
# Epoch 99/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.7281 - y1_output_loss: 0.6123 - y2_output_loss: 2.1051 - y1_output_root_mean_squared_error: 0.7845 - y2_output_root_mean_squared_error: 1.4535 - val_loss: 3.5063 - val_y1_output_loss: 0.7428 - val_y2_output_loss: 2.7982 - val_y1_output_root_mean_squared_error: 0.7922 - val_y2_output_root_mean_squared_error: 1.6967
# Epoch 100/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.5113 - y1_output_loss: 0.5079 - y2_output_loss: 2.0142 - y1_output_root_mean_squared_error: 0.7126 - y2_output_root_mean_squared_error: 1.4155 - val_loss: 5.0652 - val_y1_output_loss: 1.0464 - val_y2_output_loss: 4.0259 - val_y1_output_root_mean_squared_error: 0.9577 - val_y2_output_root_mean_squared_error: 2.0366
# Epoch 101/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.6433 - y1_output_loss: 0.5521 - y2_output_loss: 2.1219 - y1_output_root_mean_squared_error: 0.7435 - y2_output_root_mean_squared_error: 1.4459 - val_loss: 13.1014 - val_y1_output_loss: 3.5970 - val_y2_output_loss: 9.8125 - val_y1_output_root_mean_squared_error: 1.8338 - val_y2_output_root_mean_squared_error: 3.1206
# Epoch 102/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.5719 - y1_output_loss: 1.0133 - y2_output_loss: 2.5414 - y1_output_root_mean_squared_error: 1.0063 - y2_output_root_mean_squared_error: 1.5998 - val_loss: 3.1347 - val_y1_output_loss: 0.8259 - val_y2_output_loss: 2.3694 - val_y1_output_root_mean_squared_error: 0.8400 - val_y2_output_root_mean_squared_error: 1.5585
# Epoch 103/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.9683 - y1_output_loss: 0.7374 - y2_output_loss: 2.2187 - y1_output_root_mean_squared_error: 0.8605 - y2_output_root_mean_squared_error: 1.4926 - val_loss: 2.7399 - val_y1_output_loss: 0.5362 - val_y2_output_loss: 2.1755 - val_y1_output_root_mean_squared_error: 0.7070 - val_y2_output_root_mean_squared_error: 1.4967
# Epoch 104/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.1793 - y1_output_loss: 0.4430 - y2_output_loss: 1.7797 - y1_output_root_mean_squared_error: 0.6685 - y2_output_root_mean_squared_error: 1.3162 - val_loss: 7.6820 - val_y1_output_loss: 1.2295 - val_y2_output_loss: 6.4919 - val_y1_output_root_mean_squared_error: 1.0705 - val_y2_output_root_mean_squared_error: 2.5566
# Epoch 105/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.4495 - y1_output_loss: 0.5184 - y2_output_loss: 1.9180 - y1_output_root_mean_squared_error: 0.7230 - y2_output_root_mean_squared_error: 1.3881 - val_loss: 3.8980 - val_y1_output_loss: 1.3422 - val_y2_output_loss: 2.7056 - val_y1_output_root_mean_squared_error: 1.0865 - val_y2_output_root_mean_squared_error: 1.6485
# Epoch 106/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.4209 - y1_output_loss: 0.5710 - y2_output_loss: 1.8557 - y1_output_root_mean_squared_error: 0.7493 - y2_output_root_mean_squared_error: 1.3636 - val_loss: 6.9714 - val_y1_output_loss: 0.6850 - val_y2_output_loss: 6.2526 - val_y1_output_root_mean_squared_error: 0.7560 - val_y2_output_root_mean_squared_error: 2.5298
# Epoch 107/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.1176 - y1_output_loss: 0.8866 - y2_output_loss: 3.2053 - y1_output_root_mean_squared_error: 0.9422 - y2_output_root_mean_squared_error: 1.7972 - val_loss: 3.3741 - val_y1_output_loss: 0.8584 - val_y2_output_loss: 2.6031 - val_y1_output_root_mean_squared_error: 0.8721 - val_y2_output_root_mean_squared_error: 1.6166
# Epoch 108/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.0695 - y1_output_loss: 1.1265 - y2_output_loss: 2.9751 - y1_output_root_mean_squared_error: 1.0651 - y2_output_root_mean_squared_error: 1.7132 - val_loss: 10.8105 - val_y1_output_loss: 2.0508 - val_y2_output_loss: 8.9443 - val_y1_output_root_mean_squared_error: 1.3761 - val_y2_output_root_mean_squared_error: 2.9861
# Epoch 109/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.5290 - y1_output_loss: 0.5976 - y2_output_loss: 1.9181 - y1_output_root_mean_squared_error: 0.7751 - y2_output_root_mean_squared_error: 1.3886 - val_loss: 8.4509 - val_y1_output_loss: 1.8923 - val_y2_output_loss: 6.8256 - val_y1_output_root_mean_squared_error: 1.3031 - val_y2_output_root_mean_squared_error: 2.5986
# Epoch 110/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.1863 - y1_output_loss: 0.5334 - y2_output_loss: 1.6424 - y1_output_root_mean_squared_error: 0.7309 - y2_output_root_mean_squared_error: 1.2853 - val_loss: 8.2171 - val_y1_output_loss: 2.2242 - val_y2_output_loss: 5.8797 - val_y1_output_root_mean_squared_error: 1.5059 - val_y2_output_root_mean_squared_error: 2.4391
# Epoch 111/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.2377 - y1_output_loss: 0.5074 - y2_output_loss: 1.7113 - y1_output_root_mean_squared_error: 0.7153 - y2_output_root_mean_squared_error: 1.3138 - val_loss: 2.3811 - val_y1_output_loss: 0.4502 - val_y2_output_loss: 1.9407 - val_y1_output_root_mean_squared_error: 0.6237 - val_y2_output_root_mean_squared_error: 1.4114
# Epoch 112/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.4713 - y1_output_loss: 0.5987 - y2_output_loss: 1.8564 - y1_output_root_mean_squared_error: 0.7772 - y2_output_root_mean_squared_error: 1.3665 - val_loss: 4.0058 - val_y1_output_loss: 0.8171 - val_y2_output_loss: 3.1920 - val_y1_output_root_mean_squared_error: 0.8618 - val_y2_output_root_mean_squared_error: 1.8064
# Epoch 113/500
# 614/614 [==============================] - 0s 135us/sample - loss: 1.8771 - y1_output_loss: 0.4211 - y2_output_loss: 1.4559 - y1_output_root_mean_squared_error: 0.6496 - y2_output_root_mean_squared_error: 1.2063 - val_loss: 2.9693 - val_y1_output_loss: 1.0203 - val_y2_output_loss: 1.9550 - val_y1_output_root_mean_squared_error: 0.9996 - val_y2_output_root_mean_squared_error: 1.4036
# Epoch 114/500
# 614/614 [==============================] - 0s 135us/sample - loss: 1.7589 - y1_output_loss: 0.4023 - y2_output_loss: 1.3734 - y1_output_root_mean_squared_error: 0.6368 - y2_output_root_mean_squared_error: 1.1634 - val_loss: 3.6294 - val_y1_output_loss: 0.6081 - val_y2_output_loss: 3.1208 - val_y1_output_root_mean_squared_error: 0.7102 - val_y2_output_root_mean_squared_error: 1.7678
# Epoch 115/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.2852 - y1_output_loss: 0.5593 - y2_output_loss: 1.7251 - y1_output_root_mean_squared_error: 0.7493 - y2_output_root_mean_squared_error: 1.3129 - val_loss: 3.0154 - val_y1_output_loss: 0.7796 - val_y2_output_loss: 2.3144 - val_y1_output_root_mean_squared_error: 0.8089 - val_y2_output_root_mean_squared_error: 1.5366
# Epoch 116/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.0262 - y1_output_loss: 0.4463 - y2_output_loss: 1.5851 - y1_output_root_mean_squared_error: 0.6697 - y2_output_root_mean_squared_error: 1.2560 - val_loss: 5.5788 - val_y1_output_loss: 0.8451 - val_y2_output_loss: 4.8477 - val_y1_output_root_mean_squared_error: 0.8570 - val_y2_output_root_mean_squared_error: 2.2010
# Epoch 117/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.7204 - y1_output_loss: 0.6093 - y2_output_loss: 2.1447 - y1_output_root_mean_squared_error: 0.7835 - y2_output_root_mean_squared_error: 1.4514 - val_loss: 8.7306 - val_y1_output_loss: 1.4106 - val_y2_output_loss: 7.1802 - val_y1_output_root_mean_squared_error: 1.1882 - val_y2_output_root_mean_squared_error: 2.7053
# Epoch 118/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.3665 - y1_output_loss: 0.7987 - y2_output_loss: 2.5360 - y1_output_root_mean_squared_error: 0.8979 - y2_output_root_mean_squared_error: 1.6001 - val_loss: 2.3608 - val_y1_output_loss: 0.6726 - val_y2_output_loss: 1.7699 - val_y1_output_root_mean_squared_error: 0.7405 - val_y2_output_root_mean_squared_error: 1.3463
# Epoch 119/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.5961 - y1_output_loss: 0.7433 - y2_output_loss: 1.9442 - y1_output_root_mean_squared_error: 0.8353 - y2_output_root_mean_squared_error: 1.3778 - val_loss: 46.6367 - val_y1_output_loss: 18.8576 - val_y2_output_loss: 28.5078 - val_y1_output_root_mean_squared_error: 4.3096 - val_y2_output_root_mean_squared_error: 5.2976
# Epoch 120/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.3006 - y1_output_loss: 1.5043 - y2_output_loss: 3.7650 - y1_output_root_mean_squared_error: 1.2296 - y2_output_root_mean_squared_error: 1.9464 - val_loss: 2.9914 - val_y1_output_loss: 0.8410 - val_y2_output_loss: 2.2231 - val_y1_output_root_mean_squared_error: 0.8430 - val_y2_output_root_mean_squared_error: 1.5102
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4744 - y1_output_loss: 0.1408 - y2_output_loss: 0.3326 - y1_output_root_mean_squared_error: 0.3768 - y2_output_root_mean_squared_error: 0.5765 - val_loss: 1.1696 - val_y1_output_loss: 0.2847 - val_y2_output_loss: 0.9665 - val_y1_output_root_mean_squared_error: 0.4743 - val_y2_output_root_mean_squared_error: 0.9719
# Epoch 462/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3806 - y1_output_loss: 0.1047 - y2_output_loss: 0.2737 - y1_output_root_mean_squared_error: 0.3238 - y2_output_root_mean_squared_error: 0.5251 - val_loss: 1.3245 - val_y1_output_loss: 0.3995 - val_y2_output_loss: 1.0051 - val_y1_output_root_mean_squared_error: 0.5736 - val_y2_output_root_mean_squared_error: 0.9977
# Epoch 463/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3838 - y1_output_loss: 0.1105 - y2_output_loss: 0.2708 - y1_output_root_mean_squared_error: 0.3331 - y2_output_root_mean_squared_error: 0.5223 - val_loss: 1.2102 - val_y1_output_loss: 0.2818 - val_y2_output_loss: 0.9920 - val_y1_output_root_mean_squared_error: 0.4774 - val_y2_output_root_mean_squared_error: 0.9911
# Epoch 464/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3585 - y1_output_loss: 0.1033 - y2_output_loss: 0.2569 - y1_output_root_mean_squared_error: 0.3228 - y2_output_root_mean_squared_error: 0.5043 - val_loss: 1.3453 - val_y1_output_loss: 0.2705 - val_y2_output_loss: 1.1577 - val_y1_output_root_mean_squared_error: 0.4826 - val_y2_output_root_mean_squared_error: 1.0547
# Epoch 465/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.6906 - y1_output_loss: 0.1748 - y2_output_loss: 0.5104 - y1_output_root_mean_squared_error: 0.4194 - y2_output_root_mean_squared_error: 0.7175 - val_loss: 1.0436 - val_y1_output_loss: 0.2701 - val_y2_output_loss: 0.8121 - val_y1_output_root_mean_squared_error: 0.4745 - val_y2_output_root_mean_squared_error: 0.9046
# Epoch 466/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.6087 - y1_output_loss: 0.1541 - y2_output_loss: 0.4554 - y1_output_root_mean_squared_error: 0.3911 - y2_output_root_mean_squared_error: 0.6751 - val_loss: 2.3220 - val_y1_output_loss: 0.7514 - val_y2_output_loss: 1.7221 - val_y1_output_root_mean_squared_error: 0.8158 - val_y2_output_root_mean_squared_error: 1.2870
# Epoch 467/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.5771 - y1_output_loss: 0.1612 - y2_output_loss: 0.4124 - y1_output_root_mean_squared_error: 0.4034 - y2_output_root_mean_squared_error: 0.6437 - val_loss: 1.1090 - val_y1_output_loss: 0.2218 - val_y2_output_loss: 0.8858 - val_y1_output_root_mean_squared_error: 0.4382 - val_y2_output_root_mean_squared_error: 0.9576
# Epoch 468/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3149 - y1_output_loss: 0.1010 - y2_output_loss: 0.2127 - y1_output_root_mean_squared_error: 0.3180 - y2_output_root_mean_squared_error: 0.4623 - val_loss: 1.1190 - val_y1_output_loss: 0.2773 - val_y2_output_loss: 0.8488 - val_y1_output_root_mean_squared_error: 0.5081 - val_y2_output_root_mean_squared_error: 0.9278
# Epoch 469/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3573 - y1_output_loss: 0.1031 - y2_output_loss: 0.2535 - y1_output_root_mean_squared_error: 0.3221 - y2_output_root_mean_squared_error: 0.5035 - val_loss: 1.1360 - val_y1_output_loss: 0.2444 - val_y2_output_loss: 0.9048 - val_y1_output_root_mean_squared_error: 0.4649 - val_y2_output_root_mean_squared_error: 0.9591
# Epoch 470/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4203 - y1_output_loss: 0.1132 - y2_output_loss: 0.3053 - y1_output_root_mean_squared_error: 0.3379 - y2_output_root_mean_squared_error: 0.5533 - val_loss: 1.0325 - val_y1_output_loss: 0.2328 - val_y2_output_loss: 0.8158 - val_y1_output_root_mean_squared_error: 0.4420 - val_y2_output_root_mean_squared_error: 0.9149
# Epoch 471/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4492 - y1_output_loss: 0.1128 - y2_output_loss: 0.3355 - y1_output_root_mean_squared_error: 0.3327 - y2_output_root_mean_squared_error: 0.5818 - val_loss: 1.4088 - val_y1_output_loss: 0.3753 - val_y2_output_loss: 1.0578 - val_y1_output_root_mean_squared_error: 0.5820 - val_y2_output_root_mean_squared_error: 1.0345
# Epoch 472/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4395 - y1_output_loss: 0.1337 - y2_output_loss: 0.3043 - y1_output_root_mean_squared_error: 0.3654 - y2_output_root_mean_squared_error: 0.5532 - val_loss: 1.0897 - val_y1_output_loss: 0.2656 - val_y2_output_loss: 0.8605 - val_y1_output_root_mean_squared_error: 0.4661 - val_y2_output_root_mean_squared_error: 0.9340
# Epoch 473/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3620 - y1_output_loss: 0.1187 - y2_output_loss: 0.2414 - y1_output_root_mean_squared_error: 0.3452 - y2_output_root_mean_squared_error: 0.4927 - val_loss: 1.2111 - val_y1_output_loss: 0.2738 - val_y2_output_loss: 0.9500 - val_y1_output_root_mean_squared_error: 0.4905 - val_y2_output_root_mean_squared_error: 0.9851
# Epoch 474/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4141 - y1_output_loss: 0.1116 - y2_output_loss: 0.3075 - y1_output_root_mean_squared_error: 0.3327 - y2_output_root_mean_squared_error: 0.5508 - val_loss: 1.2491 - val_y1_output_loss: 0.2640 - val_y2_output_loss: 1.0067 - val_y1_output_root_mean_squared_error: 0.4850 - val_y2_output_root_mean_squared_error: 1.0069
# Epoch 475/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3850 - y1_output_loss: 0.1250 - y2_output_loss: 0.2583 - y1_output_root_mean_squared_error: 0.3529 - y2_output_root_mean_squared_error: 0.5104 - val_loss: 1.2517 - val_y1_output_loss: 0.2818 - val_y2_output_loss: 1.0510 - val_y1_output_root_mean_squared_error: 0.4762 - val_y2_output_root_mean_squared_error: 1.0123
# Epoch 476/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3271 - y1_output_loss: 0.1098 - y2_output_loss: 0.2156 - y1_output_root_mean_squared_error: 0.3320 - y2_output_root_mean_squared_error: 0.4658 - val_loss: 1.0240 - val_y1_output_loss: 0.2432 - val_y2_output_loss: 0.8022 - val_y1_output_root_mean_squared_error: 0.4478 - val_y2_output_root_mean_squared_error: 0.9075
# Epoch 477/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3359 - y1_output_loss: 0.1183 - y2_output_loss: 0.2166 - y1_output_root_mean_squared_error: 0.3438 - y2_output_root_mean_squared_error: 0.4666 - val_loss: 1.0213 - val_y1_output_loss: 0.2246 - val_y2_output_loss: 0.8095 - val_y1_output_root_mean_squared_error: 0.4378 - val_y2_output_root_mean_squared_error: 0.9108
# Epoch 478/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4673 - y1_output_loss: 0.1238 - y2_output_loss: 0.3437 - y1_output_root_mean_squared_error: 0.3501 - y2_output_root_mean_squared_error: 0.5871 - val_loss: 1.3292 - val_y1_output_loss: 0.2838 - val_y2_output_loss: 1.0898 - val_y1_output_root_mean_squared_error: 0.4959 - val_y2_output_root_mean_squared_error: 1.0408
# Epoch 479/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3451 - y1_output_loss: 0.0992 - y2_output_loss: 0.2450 - y1_output_root_mean_squared_error: 0.3138 - y2_output_root_mean_squared_error: 0.4966 - val_loss: 1.3389 - val_y1_output_loss: 0.4079 - val_y2_output_loss: 1.0266 - val_y1_output_root_mean_squared_error: 0.5725 - val_y2_output_root_mean_squared_error: 1.0055
# Epoch 480/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4694 - y1_output_loss: 0.1316 - y2_output_loss: 0.3392 - y1_output_root_mean_squared_error: 0.3614 - y2_output_root_mean_squared_error: 0.5821 - val_loss: 1.2771 - val_y1_output_loss: 0.3478 - val_y2_output_loss: 1.0133 - val_y1_output_root_mean_squared_error: 0.5316 - val_y2_output_root_mean_squared_error: 0.9972
# Epoch 481/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.2860 - y1_output_loss: 0.1001 - y2_output_loss: 0.1849 - y1_output_root_mean_squared_error: 0.3175 - y2_output_root_mean_squared_error: 0.4303 - val_loss: 1.1909 - val_y1_output_loss: 0.2976 - val_y2_output_loss: 0.9433 - val_y1_output_root_mean_squared_error: 0.5021 - val_y2_output_root_mean_squared_error: 0.9689
# Epoch 482/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3262 - y1_output_loss: 0.1082 - y2_output_loss: 0.2159 - y1_output_root_mean_squared_error: 0.3301 - y2_output_root_mean_squared_error: 0.4660 - val_loss: 0.9439 - val_y1_output_loss: 0.2370 - val_y2_output_loss: 0.7396 - val_y1_output_root_mean_squared_error: 0.4355 - val_y2_output_root_mean_squared_error: 0.8685
# Epoch 483/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.5579 - y1_output_loss: 0.1394 - y2_output_loss: 0.4191 - y1_output_root_mean_squared_error: 0.3733 - y2_output_root_mean_squared_error: 0.6469 - val_loss: 1.1571 - val_y1_output_loss: 0.2552 - val_y2_output_loss: 0.9454 - val_y1_output_root_mean_squared_error: 0.4656 - val_y2_output_root_mean_squared_error: 0.9697
# Epoch 484/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4184 - y1_output_loss: 0.1243 - y2_output_loss: 0.2938 - y1_output_root_mean_squared_error: 0.3517 - y2_output_root_mean_squared_error: 0.5429 - val_loss: 1.7243 - val_y1_output_loss: 0.3195 - val_y2_output_loss: 1.4012 - val_y1_output_root_mean_squared_error: 0.5280 - val_y2_output_root_mean_squared_error: 1.2023
# Epoch 485/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.6438 - y1_output_loss: 0.1714 - y2_output_loss: 0.4698 - y1_output_root_mean_squared_error: 0.4154 - y2_output_root_mean_squared_error: 0.6865 - val_loss: 1.3232 - val_y1_output_loss: 0.3262 - val_y2_output_loss: 1.0687 - val_y1_output_root_mean_squared_error: 0.5153 - val_y2_output_root_mean_squared_error: 1.0284
# Epoch 486/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.5223 - y1_output_loss: 0.1320 - y2_output_loss: 0.3897 - y1_output_root_mean_squared_error: 0.3612 - y2_output_root_mean_squared_error: 0.6259 - val_loss: 1.4412 - val_y1_output_loss: 0.3712 - val_y2_output_loss: 1.0764 - val_y1_output_root_mean_squared_error: 0.5853 - val_y2_output_root_mean_squared_error: 1.0481
# Epoch 487/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3194 - y1_output_loss: 0.0998 - y2_output_loss: 0.2181 - y1_output_root_mean_squared_error: 0.3167 - y2_output_root_mean_squared_error: 0.4681 - val_loss: 1.0921 - val_y1_output_loss: 0.2483 - val_y2_output_loss: 0.8538 - val_y1_output_root_mean_squared_error: 0.4639 - val_y2_output_root_mean_squared_error: 0.9364
# Epoch 488/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.2545 - y1_output_loss: 0.0982 - y2_output_loss: 0.1556 - y1_output_root_mean_squared_error: 0.3140 - y2_output_root_mean_squared_error: 0.3948 - val_loss: 1.1660 - val_y1_output_loss: 0.2736 - val_y2_output_loss: 0.9689 - val_y1_output_root_mean_squared_error: 0.4662 - val_y2_output_root_mean_squared_error: 0.9740
# Epoch 489/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4195 - y1_output_loss: 0.1210 - y2_output_loss: 0.3098 - y1_output_root_mean_squared_error: 0.3442 - y2_output_root_mean_squared_error: 0.5487 - val_loss: 1.8301 - val_y1_output_loss: 0.3423 - val_y2_output_loss: 1.4912 - val_y1_output_root_mean_squared_error: 0.5433 - val_y2_output_root_mean_squared_error: 1.2389
# Epoch 490/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.2964 - y1_output_loss: 0.0995 - y2_output_loss: 0.1992 - y1_output_root_mean_squared_error: 0.3140 - y2_output_root_mean_squared_error: 0.4448 - val_loss: 1.4447 - val_y1_output_loss: 0.3489 - val_y2_output_loss: 1.0920 - val_y1_output_root_mean_squared_error: 0.5669 - val_y2_output_root_mean_squared_error: 1.0599
# Epoch 491/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.6032 - y1_output_loss: 0.1670 - y2_output_loss: 0.4335 - y1_output_root_mean_squared_error: 0.4095 - y2_output_root_mean_squared_error: 0.6599 - val_loss: 1.1911 - val_y1_output_loss: 0.2358 - val_y2_output_loss: 0.9866 - val_y1_output_root_mean_squared_error: 0.4526 - val_y2_output_root_mean_squared_error: 0.9931
# Epoch 492/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4158 - y1_output_loss: 0.1173 - y2_output_loss: 0.3071 - y1_output_root_mean_squared_error: 0.3368 - y2_output_root_mean_squared_error: 0.5498 - val_loss: 2.5245 - val_y1_output_loss: 0.4520 - val_y2_output_loss: 2.0823 - val_y1_output_root_mean_squared_error: 0.6230 - val_y2_output_root_mean_squared_error: 1.4616
# Epoch 493/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3766 - y1_output_loss: 0.1054 - y2_output_loss: 0.2854 - y1_output_root_mean_squared_error: 0.3231 - y2_output_root_mean_squared_error: 0.5218 - val_loss: 2.4834 - val_y1_output_loss: 0.5811 - val_y2_output_loss: 2.0367 - val_y1_output_root_mean_squared_error: 0.7141 - val_y2_output_root_mean_squared_error: 1.4048
# Epoch 494/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.6752 - y1_output_loss: 0.1540 - y2_output_loss: 0.5190 - y1_output_root_mean_squared_error: 0.3942 - y2_output_root_mean_squared_error: 0.7210 - val_loss: 1.2961 - val_y1_output_loss: 0.3135 - val_y2_output_loss: 1.0271 - val_y1_output_root_mean_squared_error: 0.5280 - val_y2_output_root_mean_squared_error: 1.0086
# Epoch 495/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4776 - y1_output_loss: 0.1378 - y2_output_loss: 0.3419 - y1_output_root_mean_squared_error: 0.3708 - y2_output_root_mean_squared_error: 0.5832 - val_loss: 1.5027 - val_y1_output_loss: 0.3011 - val_y2_output_loss: 1.1844 - val_y1_output_root_mean_squared_error: 0.5256 - val_y2_output_root_mean_squared_error: 1.1074
# Epoch 496/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3438 - y1_output_loss: 0.1060 - y2_output_loss: 0.2364 - y1_output_root_mean_squared_error: 0.3263 - y2_output_root_mean_squared_error: 0.4871 - val_loss: 1.1815 - val_y1_output_loss: 0.2404 - val_y2_output_loss: 0.9362 - val_y1_output_root_mean_squared_error: 0.4612 - val_y2_output_root_mean_squared_error: 0.9843
# Epoch 497/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4305 - y1_output_loss: 0.1183 - y2_output_loss: 0.3123 - y1_output_root_mean_squared_error: 0.3443 - y2_output_root_mean_squared_error: 0.5585 - val_loss: 1.1175 - val_y1_output_loss: 0.2559 - val_y2_output_loss: 0.8789 - val_y1_output_root_mean_squared_error: 0.4711 - val_y2_output_root_mean_squared_error: 0.9463
# Epoch 498/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.6081 - y1_output_loss: 0.1606 - y2_output_loss: 0.4512 - y1_output_root_mean_squared_error: 0.4002 - y2_output_root_mean_squared_error: 0.6693 - val_loss: 2.2420 - val_y1_output_loss: 0.4324 - val_y2_output_loss: 1.9361 - val_y1_output_root_mean_squared_error: 0.5948 - val_y2_output_root_mean_squared_error: 1.3741
# Epoch 499/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.6857 - y1_output_loss: 0.1505 - y2_output_loss: 0.5303 - y1_output_root_mean_squared_error: 0.3890 - y2_output_root_mean_squared_error: 0.7310 - val_loss: 1.1111 - val_y1_output_loss: 0.2865 - val_y2_output_loss: 0.8629 - val_y1_output_root_mean_squared_error: 0.4890 - val_y2_output_root_mean_squared_error: 0.9338
# Epoch 500/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4000 - y1_output_loss: 0.1174 - y2_output_loss: 0.2900 - y1_output_root_mean_squared_error: 0.3366 - y2_output_root_mean_squared_error: 0.5355 - val_loss: 1.3205 - val_y1_output_loss: 0.3492 - val_y2_output_loss: 0.9642 - val_y1_output_root_mean_squared_error: 0.5679 - val_y2_output_root_mean_squared_error: 0.9990

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 35us/sample - loss: 1.3205 - y1_output_loss: 0.3230 - y2_output_loss: 0.9990 - y1_output_root_mean_squared_error: 0.5679 - y2_output_root_mean_squared_error: 0.9990
# Loss = 1.3204916111834637, Y1_loss = 0.32302188873291016, Y1_mse = 0.5678693652153015, Y2_loss = 0.9990471601486206, Y2_mse = 0.9990074634552002

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
